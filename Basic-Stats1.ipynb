# %% [markdown]
# ### Import Libraries for Exploring Dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0      1/4/2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1      1/4/2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2      1/4/2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3      1/4/2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4      1/4/2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
numerical_columns1=df.select_dtypes(include=['int']).columns
numerical_columns1
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value'], dtype='object')

# %%
numerical_columns1.value_counts()
# Out:
# Volume               1
# Avg Price            1
# Total Sales Value    1
# Name: count, dtype: int64

# %%
df[numerical_columns1].mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# dtype: float64

# %%
df[numerical_columns1].median()
# Out:
# Volume                  4.0
# Avg Price            1450.0
# Total Sales Value    5700.0
# dtype: float64

# %%
df[numerical_columns1].mode()
# Out:
#    Volume  Avg Price  Total Sales Value
# 0     3.0        400            24300.0
# 1     NaN        450                NaN
# 2     NaN        500                NaN
# 3     NaN       1300                NaN
# 4     NaN       8100                NaN

# %%
df[numerical_columns1].skew()
# Out:
# Volume               2.731724
# Avg Price            1.908873
# Total Sales Value    1.534729
# dtype: float64

# %%
df[numerical_columns1].kurt()
# Out:
# Volume               10.258547
# Avg Price             2.075655
# Total Sales Value     1.024916
# dtype: float64

# %%
numerical_columns2=df.select_dtypes(include=['float']).columns
numerical_columns2
# Out:
# Index(['Discount Rate (%)', 'Discount Amount', 'Net Sales Value'], dtype='object')

# %%
numerical_columns2.value_counts()
# Out:
# Discount Rate (%)    1
# Discount Amount      1
# Net Sales Value      1
# Name: count, dtype: int64

# %%
df[numerical_columns2].mean()
# Out:
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
df[numerical_columns2].median()
# Out:
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
df[numerical_columns2].mode().head(5)
# Out:
#    Discount Rate (%)  Discount Amount  Net Sales Value
# 0           5.007822        69.177942       326.974801
# 1           5.055218        73.025199       330.822058
# 2           5.059801        93.649161       466.350839
# 3           5.072124        94.682735       485.317265
# 4           5.084108       102.705757       496.607104

# %%
df[numerical_columns2].skew()
# Out:
# Discount Rate (%)   -1.062294
# Discount Amount      1.913038
# Net Sales Value      1.540822
# dtype: float64

# %%
df[numerical_columns2].kurt()
# Out:
# Discount Rate (%)   -0.178541
# Discount Amount      3.831186
# Net Sales Value      1.012468
# dtype: float64

# %%
numerical_columns3=df.select_dtypes(include=['object']).columns
numerical_columns3
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
numerical_columns3.value_counts()
# Out:
# Date     1
# Day      1
# SKU      1
# City     1
# BU       1
# Brand    1
# Model    1
# Name: count, dtype: int64

# %%
df[numerical_columns3].mode().head(5)
# Out:
#          Date       Day  SKU City         BU  Brand           Model
# 0    1/4/2021  Thursday  F01    C       FMCG  Jeera    Babaji Cream
# 1   10/4/2021       NaN  F02  NaN  Lifestyle    NaN     Babaji Oil
# 2   11/4/2021       NaN  F03  NaN    Mobiles    NaN  Babaji Shampoo
# 3   12/4/2021       NaN  F04  NaN        NaN    NaN   Gear BB Cream
# 4  13-04-2021       NaN  F05  NaN        NaN    NaN      Gear Cream

# %% [markdown]
# ### Visualizations
# ### Histograms

# %%
import matplotlib.pyplot as plt
for int in numerical_columns1:
    plt.figure(figsize=(6,6))
    plt.hist(df[int])
    plt.title(f'Histogram of {int}')
    plt.xlabel(int)
    plt.ylabel('frequency')
    plt.show()

# %%
for float in numerical_columns2:
    plt.figure(figsize=(6,5))
    plt.hist(df[float])
    plt.title(f'Histgram of {float}')
    plt.xlabel(float)
    plt.ylabel('Frequency')
    plt.show()

# %%
for object in numerical_columns3:
    plt.figure(figsize=(6,5))
    plt.hist(df[object])
    plt.title(f'Histogram of {object}')
    plt.xlabel(object)
    plt.ylabel('frequency')
    plt.show()

# %% [markdown]
# ### Boxplots With Outliers

# %%
numerical_columns1
plt.figure(figsize=(6,5))
plt.boxplot(df['Avg Price'])
plt.title('Boxplot of Avg Price')
plt.xlabel('value')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df['Volume'])
plt.title('Boxplot of Volume')
plt.xlabel('Value')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df['Total Sales Value'])
plt.title('Boxplot of Total Sales Value')
plt.xlabel('Value')
plt.show()

# %%
numerical_columns2;
plt.figure(figsize=(6,5))
plt.boxplot(df['Discount Amount'])
plt.title('Boxplot of Discount Amount')
plt.xlabel('Value')
plt.show()

# %%
numerical_columns2;
plt.figure(figsize=(5,5))
plt.boxplot(df['Net Sales Value'])
plt.title('Boxplot of Net Sale Value')
plt.xlabel('value')
plt.show()

# %%
numerical_columns2;
plt.figure(figsize=(5,5))
plt.boxplot(df['Discount Rate (%)'])
plt.title('Boxplot of Discount Rate (%)')
plt.xlabel('value')
plt.show()

# %% [markdown]
# ### Barchats for analysis the catagorical columns

# %%
catagorical_columns1=df.select_dtypes(include=('int')).columns
catagorical_columns1
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value'], dtype='object')

# %%
catagorical_columns2=df.select_dtypes(include=('float')).columns
catagorical_columns2
# Out:
# Index(['Discount Rate (%)', 'Discount Amount', 'Net Sales Value'], dtype='object')

# %%
catagorical_columns3=df.select_dtypes(include=('object')).columns
catagorical_columns3
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
catagorical_columns1
df[int].value_counts()
plt.bar(df.index,df[int])
plt.show()

# %%
df['Avg Price'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Avg Price'>

# %%
df['Volume'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Volume'>

# %%
catagorical_columns2
df[float]
plt.bar(df.index,df[float])
plt.show()

# %%
df[object].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
df.BU.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BU'>

# %%
df.City.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
catagorical_columns3
df[object]
plt.bar(df.index,df[object])
plt.show()

# %% [markdown]
# ### Standardization

# %%
standardize_columns1=df.select_dtypes(include=['int'])
standardize_columns1
# Out:
#      Volume  Avg Price  Total Sales Value
# 0        15      12100             181500
# 1        10      10100             101000
# 2         7      16100             112700
# 3         6      20100             120600
# 4         3       8100              24300
# ..      ...        ...                ...
# 445       2       1300               2600
# 446       6       2600              15600
# 447       2       1600               3200
# 448       3       1900               5700
# 449       1       3100               3100
#
# [450 rows x 3 columns]

# %%
def standardize_columns1(int):
    mean = int.mean()
    std_dev = int.std()
    standardized_columns1 = (int - mean) / std_dev
    return standardized_columns1

# %%
for int in numerical_columns1:
    df[int] = standardize_columns1(df[int])

df[numerical_columns1].head()
# Out:
#      Volume  Avg Price  Total Sales Value
# 0  2.347417   0.091072           2.922469
# 1  1.165831  -0.019548           1.329516
# 2  0.456880   0.312312           1.561038
# 3  0.220563   0.533552           1.717365
# 4 -0.488389  -0.130168          -0.188242

# %%
standardize_columns2=df.select_dtypes(include=['float'])
standardize_columns2
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.347417   0.091072           2.922469          11.654820
# 1    1.165831  -0.019548           1.329516          11.560498
# 2    0.456880   0.312312           1.561038           9.456886
# 3    0.220563   0.533552           1.717365           6.935385
# 4   -0.488389  -0.130168          -0.188242          17.995663
# ..        ...        ...                ...                ...
# 445 -0.724706  -0.506277          -0.617647          15.475687
# 446  0.220563  -0.434374          -0.360400          17.057027
# 447 -0.724706  -0.489684          -0.605774          18.965550
# 448 -0.488389  -0.473091          -0.556303          16.793014
# 449 -0.961023  -0.406719          -0.607753          15.333300
#
#      Discount Amount  Net Sales Value
# 0       21153.498820    160346.501200
# 1       11676.102960     89323.897040
# 2       10657.910160    102042.089800
# 3        8364.074702    112235.925300
# ...

# %%
def standardize_columns2(float):
    mean = float.mean()
    std_dev = float.std()
    standardized_columns2 = (float - mean) / std_dev
    return standardized_columns2

# %%
for float in numerical_columns2:
    df[float]=standardize_columns2(df[float])

df[numerical_columns2].head()
# Out:
#    Discount Rate (%)  Discount Amount  Net Sales Value
# 0          -0.829365         3.948422         2.801638
# 1          -0.851714         1.846958         1.269613
# 2          -1.350129         1.621190         1.543957
# 3          -1.947555         1.112568         1.763847
# 4           0.672990         0.227598        -0.227342

# %%
standardize_columns3=df.select_dtypes(include=['object'])
standardize_columns3
# Out:
#            Date       Day  SKU City         BU  Brand       Model
# 0      1/4/2021  Thursday  M01    C    Mobiles  RealU       RU-10
# 1      1/4/2021  Thursday  M02    C    Mobiles  RealU   RU-9 Plus
# 2      1/4/2021  Thursday  M03    C    Mobiles   YouM       YM-99
# 3      1/4/2021  Thursday  M04    C    Mobiles   YouM  YM-99 Plus
# 4      1/4/2021  Thursday  M05    C    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
### converting All columns in All_columns123

# %%
All_columns123=df.select_dtypes(include=['int','float','object']).columns
All_columns123
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %% [markdown]
# ### Converting Numerical Columns Into Dummy Variables

# %%
# Converting numerical columns into dummy variables
dummy_df = pd.get_dummies(df[All_columns123])
# Concatenating the original DataFrame with the dummy variables
df_with_dummies = pd.concat([df.drop(All_columns123, axis=1), dummy_df], axis=1)
# Now, df_with_dummies contains the original DataFrame with numerical columns converted to dummy variables
print(df_with_dummies.head())
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.347417   0.091072           2.922469          -0.829365         3.948422
# 1  1.165831  -0.019548           1.329516          -0.851714         1.846958
# 2  0.456880   0.312312           1.561038          -1.350129         1.621190
# 3  0.220563   0.533552           1.717365          -1.947555         1.112568
# 4 -0.488389  -0.130168          -0.188242           0.672990         0.227598
#
#    Net Sales Value  Date_1/4/2021  Date_10/4/2021  Date_11/4/2021  \
# 0         2.801638           True           False           False
# 1         1.269613           True           False           False
# 2         1.543957           True           False           False
# 3         1.763847           True           False           False
# 4        -0.227342           True           False           False
#
#    Date_12/4/2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %% [markdown]
# ### Summarize

# %% [markdown]
# #### *Inferences all the numerical features have right skewness except for discount is left skewed. Also we can see from discount that there could be outliers
